# %% [markdown]
# ### Description : This python notebook includes the comparative study of line detection technique by using canny edge detection and hough-transform.We have taken 3 sample input images for the purpose,We can have a closer look at the outputs.

# %% [markdown]
# ### Author : Riya Chougule

# %% [markdown]
# ### Date : 18/8/2020

# %% [markdown]
# ### 1. Lines detection using Canny edge detection method

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img1 = cv2.imread('inv10.jpg')
edges1 = cv2.Canny(img1,25,255,L2gradient=True)
NUM_ROWS = 1
IMGs_IN_ROW = 2
f, ax = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))

ax[0].imshow(img1)
ax[1].imshow(edges1)

ax[0].set_title('Original image')
ax[1].set_title('Edge Detected image')
# Out:
# Text(0.5, 1.0, 'Edge Detected image')

# %%
img2 = cv2.imread('inv20.jpg')
edges2 = cv2.Canny(img2,25,255,L2gradient=True)
NUM_ROWS = 1
IMGs_IN_ROW = 2
f, ax = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))

ax[0].imshow(img2)
ax[1].imshow(edges2)

ax[0].set_title('Original image')
ax[1].set_title('Edge Detected image')
# Out:
# Text(0.5, 1.0, 'Edge Detected image')

# %%
img3 = cv2.imread('inv8.jpg')
edges3 = cv2.Canny(img3,25,255,L2gradient=True)
NUM_ROWS = 1
IMGs_IN_ROW = 2
f, ax = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))

ax[0].imshow(img3)
ax[1].imshow(edges3)

ax[0].set_title('Original image')
ax[1].set_title('Edge Detected image')
# Out:
# Text(0.5, 1.0, 'Edge Detected image')

# %% [markdown]
# ### 2. Lines detection using Hough transform method

# %%
img4 = cv2.imread("inv10.jpg")
grayscale4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
edges4 = cv2.Canny(grayscale4, 30, 100)
lines4 = cv2.HoughLinesP(edges4, 1, np.pi/180, 60, np.array([]), 50, 5)
for line in lines4:
    for x1, y1, x2, y2 in line:
        res4=cv2.line(img4, (x1, y1), (x2, y2), (20, 220, 20), 3)
NUM_ROWS = 1
IMGs_IN_ROW = 2
f4, ax4 = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))
img4 = cv2.imread("inv10.jpg")
ax4[0].imshow(img4)
ax4[1].imshow(res4)

ax4[0].set_title('Original image')
ax4[1].set_title('Edge Detected image')
# Out:
# Text(0.5, 1.0, 'Edge Detected image')

# %%
img5 = cv2.imread("inv20.jpg")
grayscale5 = cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)
edges5 = cv2.Canny(grayscale5, 30, 100)
lines5 = cv2.HoughLinesP(edges5, 1, np.pi/180, 60, np.array([]), 50, 5)
for line in lines5:
    for x1, y1, x2, y2 in line:
        res5=cv2.line(img5, (x1, y1), (x2, y2), (20, 220, 20), 3)
NUM_ROWS = 1
IMGs_IN_ROW = 2
f5, ax5 = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))
img5 = cv2.imread("inv20.jpg")
ax5[0].imshow(img5)
ax5[1].imshow(res5)

ax5[0].set_title('Original image')
ax5[1].set_title('Edge Detected image')
# Out:
# Text(0.5, 1.0, 'Edge Detected image')

# %%
img6 = cv2.imread("inv8.jpg")
grayscale6 = cv2.cvtColor(img6, cv2.COLOR_BGR2GRAY)
edges6 = cv2.Canny(grayscale6, 30, 100)
lines6 = cv2.HoughLinesP(edges6, 1, np.pi/180, 60, np.array([]), 50, 5)
for line in lines6:
    for x1, y1, x2, y2 in line:
        res6=cv2.line(img6, (x1, y1), (x2, y2), (20, 220, 20), 3)
NUM_ROWS = 1
IMGs_IN_ROW = 2
f6, ax6 = plt.subplots(NUM_ROWS, IMGs_IN_ROW, figsize=(16,6))
img6 = cv2.imread("inv8.jpg")
ax6[0].imshow(img6)
ax6[1].imshow(res6)

ax6[0].set_title('Original image')
ax6[1].set_title('Edge Detected image')
# Out:
# Text(0.5, 1.0, 'Edge Detected image')

# %% [markdown]
# ### Conclusion : We compared the line detection algorithms on 3 sample input images and,according to these results,we observe that Hough-transform is comparatively stronger than Canny edge detection
