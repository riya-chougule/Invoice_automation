# %% [markdown]
# ### Description : This notebook contains different types of blurring methods which are used under finen tuning of an image in preprocessing stage.I have used three methods for blurring an image provided by OpenCv.

# %% [markdown]
# ### Author : Riya Chougule

# %% [markdown]
# ### Date : 31/5/2020

# %% [markdown]
# ### 1. Averaging

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('rgb.png')

# %%
blur1 = cv2.blur(img,(5,5))

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur1),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 2.Gaussian flitering

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('rgb.png')

# %%
blur2 = cv2.GaussianBlur(img,(5,5),0)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur2),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### 3. Median filtering

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('rgb.png')

# %%
blur3 = cv2.bilateralFilter(img,9,75,75)

# %%
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur3),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### The outcome of this notebook can be viewd in a glance as follows :

# %% [markdown]
# ### Output of averaging

# %%
imgplot = plt.imshow(blur1)

# %% [markdown]
# ### Output of Gaussian filtering

# %%
imgplot = plt.imshow(blur2)

# %% [markdown]
# ### Output of bilateral filtering

# %%
imgplot = plt.imshow(blur3)
