# %% [markdown]
# ### Description : This notebook contains the image to text conversion using pytesseract.Here we have taken an image of an invoice as an input, it gives the text as an ouput

# %% [markdown]
# ### Author : Riya Chougule

# %% [markdown]
# ### Date : 13/6/2020

# %%
 pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\lib\site-packages (6.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
 pip install pytesseract
# Out:
# Requirement already satisfied: pytesseract in c:\users\admin\anaconda3\lib\site-packages (0.3.4)
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (from pytesseract) (6.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract as tess
from matplotlib import pyplot as plt

# %%
from PIL import Image

# %%
img= Image.open('paper_part1.jpg')

# %%
text = tess.image_to_string(img)

# %%
imgplot = plt.imshow(img)

# %%
print(text)
# Out:
# TILAK MAHARASHTRA VIDYAPEETH, PUNE OLD
#
# BACHELOR OF LAWS (LL.B.) (Three Years Semester Pattern)
#
# EXAMINATION : APRIL — 2015
#
# SIXTH SEMESTER
# Sub.: The Code Criminal Procedure, 1973, Juvenile Justice Act, 2000 and
# Probation of Offenders Act, 1958 (LW-601)
#
#
#
# fe : 22/ 4/2015 Total Marks : 60 Time: 10.00 am to 12.30 pm
#
#
#
# itructions: 1) All questions are compulsory.
# 2) Figure indicate to the right full marks.
# 1. Choose correct option from the following. (10)
#
# !) In cases triable by the Sessions Court if the accused is poor and without any means of his
# own he will be entitled to.
#
# 4) Free Legal Aid b) Financial Assistance
# c) Legal help d) Fight his case

# %%
img2= Image.open('paper_part2.jpg')

# %%
text2 = tess.image_to_string(img2)

# %%
imgplot = plt.imshow(img2)

# %%
print(text2)
# Out:
# !) A judicial proceeding which ends in conviction or acquittal of the accused is called as ------
#
# a) Order b) Decision
# ) Trial d) Award
# !) Police report means a report forwarded by a police officer to a magistrate under----------- :
# A) Subsection (2) of section 173 of Cr.P.C. b) Subsection (2) of section 153 of Cr. P.C.
# c) Subsection (2) of section 175 of Cr.P.C. d) Subsection (2) of section 178 of Cr. P.C.
#
# |) | According to section 43 of Cr.P.C. a private person may arrest a person only when the
# person is a proclaimed offender or ----------------- :
#
# a) If the person commits cognizable and b) If the person commits non - cognizable
# bailable offence in view. and non - bailable offence in his view.
#
# Vv) If the person commits cognizable and d) If the person commits non - cognizable
# non - bailable offence in his view. and bailable offence in his view.
