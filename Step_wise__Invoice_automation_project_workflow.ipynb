# %% [markdown]
# ### Description : This notebook includes the step wise workflow of the project invoice automation.Also I have used Opencv,numpy,matplotlib,pytesseract and Pillow libraries in this code.

# %% [markdown]
# ### Date : 14/11/2020

# %% [markdown]
# ### Author : Riya Chougule

# %% [markdown]
# ## 1.Conversion of sample image to binary form

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import pytesseract
pytesseract.pytesseract.tesseract_cmd="C:\\Program Files\\Tesseract-OCR\\tesseract.exe"

image = cv2.imread('inv20.jpg',0)
ret,thresh1 = cv2.threshold(image,110,255,cv2.THRESH_BINARY)
original1 = Image.fromarray(image)
#original1

# %%
img1 = Image.fromarray(thresh1)
#img1

# %% [markdown]
# ## 2.Detecting lines from the invoice sample

# %% [markdown]
# #### --- to do ---

# %% [markdown]
# ## 3.Form individual subregions corresponding to sections present in the invoice

# %%
#img1_crop1 = img1.crop((70, 140, 2560, 690))
#img1_crop1

# %%
image1=cv2.imread("sample1.png")
image1 = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray = cv2.cvtColor(image1, cv2.COLOR_RGB2GRAY)
_, binary1 = cv2.threshold(gray, 235, 255, cv2.THRESH_BINARY_INV)
contours1, hierarchy1 = cv2.findContours(binary1, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# draw all contours
image1 = cv2.drawContours(image1, contours1, -1, (0, 255, 0), 2)
result1=Image.fromarray(image1)
#result1

# %%
img1_crop2 = img1.crop((2547, 150, 3900, 676))
#img1_crop2

# %%
image2=cv2.imread("sample2.png")
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray2 = cv2.cvtColor(image2, cv2.COLOR_RGB2GRAY)
_, binary2 = cv2.threshold(gray2, 235, 255, cv2.THRESH_BINARY_INV)
contours2, hierarchy2 = cv2.findContours(binary2, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# draw all contours
image2 = cv2.drawContours(image2, contours2, -1, (0, 255, 0), 2)
result2=Image.fromarray(image2)
#result2

# %%
img1_crop3 = img1.crop((50, 662, 3900, 1021))
#img1_crop3

# %%
image3=cv2.imread("sample3.png")
image3 = cv2.cvtColor(image3, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray3 = cv2.cvtColor(image3, cv2.COLOR_RGB2GRAY)
_, binary3 = cv2.threshold(gray3, 210, 255, cv2.THRESH_BINARY_INV)
contours3, hierarchy3 = cv2.findContours(binary3, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# draw all contours
image3 = cv2.drawContours(image3, contours3, -1, (0, 255, 0), 2)
result3=Image.fromarray(image3)
#result3

# %%
img1_crop4 = img1.crop((50,990, 3940, 2252))
#img1_crop4

# %%
image4=cv2.imread("sample4.png")
image4 = cv2.cvtColor(image4, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray4 = cv2.cvtColor(image4, cv2.COLOR_RGB2GRAY)
_, binary4 = cv2.threshold(gray4, 210, 255, cv2.THRESH_BINARY_INV)
contours4, hierarchy4 = cv2.findContours(binary4, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# draw all contours
image4 = cv2.drawContours(image4, contours4, -1, (0, 255, 0), 2)
result4=Image.fromarray(image4)
#result4

# %%
img1_crop5 = img1.crop((40, 2232, 3919, 2878))
#img1_crop5

# %%
image5=cv2.imread("sample5.png")
image5 = cv2.cvtColor(image5, cv2.COLOR_BGR2RGB)
# convert to grayscale
gray5 = cv2.cvtColor(image5, cv2.COLOR_RGB2GRAY)
_, binary5 = cv2.threshold(gray5, 210, 255, cv2.THRESH_BINARY_INV)
contours5, hierarchy5 = cv2.findContours(binary5, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
# draw all contours
image5 = cv2.drawContours(image5, contours5, -1, (0, 255, 0), 2)
result5=Image.fromarray(image5)
#result5

# %% [markdown]
# ## 4.Creating a series of image sub-regions

# %%
fig = plt.figure(figsize=(30,25))
ax = fig.add_subplot(3,2,1)
ax.imshow(image1)
ax.set_title('Sub-region 1')
ax1 = fig.add_subplot(3,2,2)
ax1.imshow(image2)
ax1.set_title('Sub-region 2')
ax2 = fig.add_subplot(3,2,3)
ax2.imshow(image3)
ax2.set_title('Sub-region 3')
ax3 = fig.add_subplot(3,2,4)
ax3.imshow(image4)
ax3.set_title('Sub-region 4')
ax4 = fig.add_subplot(3,2,5)
ax4.imshow(image5)
ax4.set_title('Sub-region 5')
# Out:
# Text(0.5, 1.0, 'Sub-region 5')

# %% [markdown]
# ## 5. Apply separate OCR for each sub-region

# %%
im1=cv2.imread("sample1.png")
boxes1=pytesseract.image_to_data(im1)         #It stores info about image like page number,line number,par number,level
for x1,b1 in enumerate(boxes1.splitlines()):   # X1 is counter variable
    if x1!=0:
        b1=b1.split()
        if len(b1)==12:
            x1,y1,w1,h1=int(b1[6]),int (b1[7]),int (b1[8]),int (b1[9])
            cv2.rectangle(im1,(x1,y1),(w1+x1,h1+y1),(0,0,255),2)
            cv2.putText(im1,b1[11],(x1,y1),cv2.FONT_HERSHEY_COMPLEX,1,(117,13,40),2)
image_with_clusters1 = Image.fromarray(im1)
image_with_clusters1
# Out:
# <PIL.Image.Image image mode=RGB size=2490x550 at 0x1ED43233E88>

# %%
im2=cv2.imread("sample2.png")
boxes2=pytesseract.image_to_data(im2)         #It stores info about image like page number,line number,par number,level
for x2,b2 in enumerate(boxes2.splitlines()):   # X1 is counter variable
    if x2!=0:
        b2=b2.split()
        if len(b2)==12:
            x2,y2,w2,h2=int(b2[6]),int (b2[7]),int (b2[8]),int (b2[9])
            cv2.rectangle(im2,(x2,y2),(w2+x2,h2+y2),(0,0,255),2)
            cv2.putText(im2,b2[11],(x2,y2),cv2.FONT_HERSHEY_COMPLEX,1,(117,13,40),2)
image_with_clusters2 = Image.fromarray(im2)
image_with_clusters2
# Out:
# <PIL.Image.Image image mode=RGB size=1353x526 at 0x1ED43285588>

# %%
im3=cv2.imread("sample3.png")
boxes3=pytesseract.image_to_data(im3)         #It stores info about image like page number,line number,par number,level
for x3,b3 in enumerate(boxes3.splitlines()):   # X1 is counter variable
    if x3!=0:
        b3=b3.split()
        if len(b3)==12:
            x3,y3,w3,h3=int(b3[6]),int (b3[7]),int (b3[8]),int (b3[9])
            cv2.rectangle(im3,(x3,y3),(w3+x3,h3+y3),(0,0,255),2)
            cv2.putText(im3,b3[11],(x3,y3),cv2.FONT_HERSHEY_COMPLEX,1,(117,13,40),2)
image_with_clusters3 = Image.fromarray(im3)
image_with_clusters3
# Out:
# <PIL.Image.Image image mode=RGB size=3850x359 at 0x1ED432667C8>

# %%
im4=cv2.imread("sample4.png")
boxes4=pytesseract.image_to_data(im4)         #It stores info about image like page number,line number,par number,level
for x4,b4 in enumerate(boxes4.splitlines()):   # X1 is counter variable
    if x4!=0:
        b4=b4.split()
        if len(b4)==12:
            x4,y4,w4,h4=int(b4[6]),int (b4[7]),int (b4[8]),int (b4[9])
            cv2.rectangle(im4,(x4,y4),(w4+x4,h4+y4),(0,0,255),2)
            cv2.putText(im4,b4[11],(x4,y4),cv2.FONT_HERSHEY_COMPLEX,1,(117,13,40),2)
image_with_clusters4 = Image.fromarray(im4)
image_with_clusters4
# Out:
# <PIL.Image.Image image mode=RGB size=3890x1262 at 0x1ED40FB1188>

# %%
im5=cv2.imread("sample5.png")
boxes5=pytesseract.image_to_data(im5)         #It stores info about image like page number,line number,par number,level
for x5,b5 in enumerate(boxes5.splitlines()):   # X1 is counter variable
    if x5!=0:
        b5=b5.split()
        if len(b5)==12:
            x5,y5,w5,h5=int(b5[6]),int (b5[7]),int (b5[8]),int (b5[9])
            cv2.rectangle(im5,(x5,y5),(w5+x5,h5+y5),(0,0,255),2)
            cv2.putText(im5,b5[11],(x5,y5),cv2.FONT_HERSHEY_COMPLEX,1,(117,13,40),2)
image_with_clusters5 = Image.fromarray(im5)
image_with_clusters5
# Out:
# <PIL.Image.Image image mode=RGB size=3879x646 at 0x1ED4325DD48>

# %% [markdown]
# ## 6. Output assembly and representation

# %% [markdown]
# #### --- To do ---
