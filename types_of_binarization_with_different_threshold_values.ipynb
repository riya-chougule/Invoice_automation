# %% [markdown]
# ### Description : This notebook contains fine tuning of an image in pre-processing stage.I have used 3 types of thresholding methods in this notebook.

# %% [markdown]
# ### Author : Riya Chougule

# %% [markdown]
# ### Date : 31/5/2020

# %% [markdown]
# ### 1. Simple threshold

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('inv8.jpg',0)
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

# %%
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

# %%
for x in range(6):
    plt.subplot(2,3,x+1),plt.imshow(images[x],'gray')
    plt.title(titles[x])
    plt.xticks([]),plt.yticks([])

# %%
titles = ['Original Image']
images = [img]

# %%
for x in range(1):
    plt.subplot(1,1,x+1),plt.imshow(images[x],'gray')
    plt.title(titles[x])
    plt.xticks([]),plt.yticks([])

# %%
titles = ['BINARY']
images = [thresh1]

# %%
for x in range(1):
    plt.subplot(1,1,x+1),plt.imshow(images[x],'gray')
    plt.title(titles[x])
    plt.xticks([]),plt.yticks([])

# %% [markdown]
# ### 2. Adaptive threshold

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('inv8.jpg',0)
img = cv2.medianBlur(img,5)

# %%
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)

# %%
titles = ['Original Image','Adaptive Mean Thresholding']
images = [img,th2]

# %%
for x in range(1):
    plt.subplot(1,1,x+1),plt.imshow(images[x],'gray')
    plt.title(titles[x])
    plt.xticks([]),plt.yticks([])

# %%
titles = ['Adaptive Mean Thresholding']
images = [th2]

# %%
for x in range(1):
    plt.subplot(1,1,x+1),plt.imshow(images[x],'gray')
    plt.title(titles[x])
    plt.xticks([]),plt.yticks([])

# %% [markdown]
# ### 3. Otsu threshold

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('inv8.jpg',0)

# %%
ret2,th3 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
images = [img]
titles = ['Original Noisy Image']

# %%
for i in range(1):
    plt.subplot(1,2,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
images = [th3]
titles = ['Otsu Thresholding']

# %%
for i in range(1):
    plt.subplot(1,2,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# ### The outcome of this notebook can be viewd at a glance as follows :

# %% [markdown]
# ### Output of simple threshold

# %%
imgplot = plt.imshow(thresh1)

# %% [markdown]
# ### Output of adaptive thrshold

# %%
imgplot = plt.imshow(th2)

# %% [markdown]
# ### Output of Otsu threshold

# %%
imgplot = plt.imshow(th3)
