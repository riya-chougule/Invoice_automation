# %% [markdown]
# ### Description : This notebook contains the method of detecting rectangles in an invoice sample, which will be used for invoice automation.

# %% [markdown]
# ### Date : 20/11/2020

# %% [markdown]
# ### Author : Riya Chougule

# %%
import cv2
from PIL import Image
image = cv2.imread('inv10_binary.png')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (3, 3), 0)
canny = cv2.Canny(blurred, 120, 255, 1)

# Find contours
cnts = cv2.findContours(canny, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

# Iterate thorugh contours and draw rectangles around contours
for c in cnts:
    x,y,w,h = cv2.boundingRect(c)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 3)

# %%
res=Image.fromarray(image)
res
# Out:
# <PIL.Image.Image image mode=RGB size=4072x2834 at 0x1E1CB3353C8>
