# %% [markdown]
# ## Description : This notebook contains  methods with which we can load an image into an array

# %% [markdown]
# ## Author name : Riya Chougule

# %% [markdown]
# ## Date : 22/05/2020

# %%
from PIL import Image

# %%
image1 = Image.open('inv1.jpg')
image2 = Image.open('inv2.jpg')

# %% [markdown]
# #### Note : Here image is a variable and Image is a class

# %%
print(image1.format)
print(image2.format)
# Out:
# JPEG
# JPEG

# %%
print(image1.mode)
print(image2.mode)
# Out:
# RGB
# RGB

# %%
print(image1.size)
print(image2.size)
# Out:
# (900, 640)
# (799, 747)

# %%
image1.show()
image2.show()

# %%
from matplotlib import image

# %%
data = image.imread('inv1.jpg')

# %%
print(data.dtype)
# Out:
# uint8

# %%
print(data.shape)
# Out:
# (640, 900, 3)

# %%
pyplot.imshow(data)
