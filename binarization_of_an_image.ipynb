# %% [markdown]
# ### Description : This notebook contains the traversing of an image pixel by pixel.Also we can study binarization process in this notebook.

# %% [markdown]
# ### Author name : Riya Chougule

# %% [markdown]
# ### Date : 27/5/2020

# %%
import PIL
from PIL import Image
import requests
from io import BytesIO
from PIL import ImageFilter
from PIL import ImageEnhance
from IPython.display import display
import numpy as np

# %%
img = Image.open('inv8.jpg')

# %%
def binarize(image_to_transform, threshold):
    output_image=image_to_transform.convert("L")
  
    for x in range(output_image.width):
        for y in range(output_image.height):
            if output_image.getpixel((x,y))< threshold: 
                output_image.putpixel( (x,y), 0 )
            else:
                
                output_image.putpixel( (x,y), 255 )
   
    return output_image
 
binarize(img, 126)
# Out:
# <PIL.Image.Image image mode=L size=932x661 at 0x2164E4118C8>
